# %% [markdown]
# # DATA-445 In-Class Assignment 5
#
# Consider the `CarPrice_Assignment.csv` data file (under the In-Class 5 assignment link). This data is publicly available on the Kaggle website, and has information on cars (characteristics related to car dimensions, engine and more). The goal is to use car information to predict the price of the car. **In Python**, answer the following:

# %% [markdown]
# ## 1. (5 points)
#
# Using the pandas library, read the csv data file and create a data-frame called `car_price`.

# %% [markdown]
# ## 2. (7 points)
#
# Using `wheelbase`, `horsepower`, `peakrpm`, `citympg`, and `highwaympg` as the predictor variables, and `price` is the target variable build a linear regression model. Perform a 5-fold cross validation. Report the RMSE of this model.

# %% [markdown]
# ## 3. (7 points)
#
# Using `carwidth`, `carheight`, `horsepower`, `citympg`, and `highwaympg` as the predictor variables, and `price` is the target variable build a linear regression model. Perform a 5-fold cross validation. Report the RMSE of this model.

# %% [markdown]
# ## 4. (3 points)
#
# Using the results from parts (2) and (3), what model would you use to predict car prices? Explain.

# %% [markdown]
# *Your answer here.*
